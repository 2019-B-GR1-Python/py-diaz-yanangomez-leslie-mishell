# %% [markdown]
# ## Clasificación Imágenes
# * Se pixelan (la mayoria de formatos)
# * No se pixelan (generalmente svg - imagenes vectoriales, se recrean mientras se les hace zoom)

# %%
## Poner que hay que hacer para llegar a esto (ejem: un rompecabezas)
import numpy as np

# %%
from scipy import ndimage
from scipy import misc

# %%
mapache = misc.face()
mapache
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
# ...

# %%
mapache.shape
# Out:
# (768, 1024, 3)

# %%
type(mapache)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Dibujar el mapache

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(mapache)

# %%
plt.imshow(mapache[::-1])

# %%
mapache1, mapache2 = np.hsplit(mapache, 2)
plt.imshow(mapache1)

# %%
plt.imshow(mapache2)

# %%
m1, m2, m3, m4 = np.split(mapache, 4)

# %%
plt.imshow(m1)

# %%
plt.imshow(m2)

# %%
plt.imshow(m3)

# %%
plt.imshow(m4)

# %%
m1p1, m1p2, m1p3, m1p4 = np.hsplit(m1,4)
m2p1, m2p2, m2p3, m2p4 = np.hsplit(m2,4)
m3p1, m3p2, m3p3, m3p4 = np.hsplit(m3,4)
m4p1, m4p2, m4p3, m4p4 = np.hsplit(m4,4)
m4p1.shape
rompecabezas = np.array([m1p1, m2p2, m3p3, m4p4])
plt.imshow(m2p1)

# %%
plt.imshow(m2p2)

# %%
plt.imshow(m2p3)

# %%
plt.imshow(m2p4)

# %%
plt.imshow(mapache[50:500,400:850])
